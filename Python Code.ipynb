# %% [markdown]
# # Task- 1.1

# %% [markdown]
# ### Task- 1.1.1 : Identifying the Ideal Functions Based on Training Data

# %%
import pandas as pd
import numpy as np

# %%
train_data = pd.read_csv("train.csv")
ideal_data = pd.read_csv("ideal.csv")
test_data = pd.read_csv("test.csv")

# %%
class IdealFunctionSelector:
    def __init__(self, train_data, ideal_data):
        self.train_data = train_data
        self.ideal_data = ideal_data

    def select_ideal_functions(self):
        """
        Select the four ideal functions minimizing the sum of squared deviations.
        """
        selected_functions = []
        max_deviations = []

        for train_column in self.train_data.columns[1:]:  
            train_y = self.train_data[train_column].values
            best_function = None
            min_sse = float('inf')
            max_deviation = 0

            for ideal_column in self.ideal_data.columns[1:]:  
                ideal_y = self.ideal_data[ideal_column].values
                sse = np.sum((train_y - ideal_y) ** 2)

                if sse < min_sse:
                    min_sse = sse
                    best_function = ideal_column
                    max_deviation = np.max(np.abs(train_y - ideal_y))

            selected_functions.append(best_function)
            max_deviations.append(max_deviation)

        return selected_functions, max_deviations

# %%
selector = IdealFunctionSelector(train_data, ideal_data)
selected_functions, max_deviations = selector.select_ideal_functions()

# %%
chosen_ideal_functions = [
    ideal_data[['x', func_name]].rename(columns={func_name: 'y'})
    for func_name in selected_functions
]

# %%
print("Selected Ideal Functions:", selected_functions)
print("Maximum Deviations:", max_deviations)
# Out:
# Selected Ideal Functions: ['y42', 'y41', 'y11', 'y48']
# Maximum Deviations: [0.4959680000000013, 0.49770300000000134, 0.4989360000000005, 0.49974158999999996]

# %% [markdown]
# ### Task-1.1.2 : Mapping Test Data to Ideal Functions

# %%
class IdealFunctionMapper:
    def __init__(self, ideal_functions, max_deviations):
        self.ideal_functions = ideal_functions
        self.max_deviations = max_deviations

    def map_test_data(self, test_data):
        """
        Map each test data point to the closest ideal function if it satisfies the deviation criterion.
        """
        results = []
        sqrt_2 = np.sqrt(2)

        for _, row in test_data.iterrows():
            x, y = row['x'], row['y']
            best_function = None
            min_deviation = float('inf')

            for i, ideal_function in enumerate(self.ideal_functions):
                if x in ideal_function['x'].values:
                    ideal_y = ideal_function.loc[ideal_function['x'] == x, 'y'].values[0]
                    deviation = abs(y - ideal_y)

                    if deviation <= self.max_deviations[i] * sqrt_2 and deviation < min_deviation:
                        best_function = f"ideal_function_{i + 1}"
                        min_deviation = deviation

            results.append({
                'x': x,
                'y': y,
                'mapped_function': best_function,
                'deviation': min_deviation if best_function else None
            })

        return pd.DataFrame(results)

# %%
mapper = IdealFunctionMapper(chosen_ideal_functions, max_deviations)
mapped_results = mapper.map_test_data(test_data)

# %%
mapped_results.head(12)
# Out:
#        x          y   mapped_function  deviation
# 0   17.5  34.161040  ideal_function_2   0.351148
# 1    0.3   1.215102  ideal_function_2   0.467342
# 2   -8.7 -16.843908              None        NaN
# 3  -19.2 -37.170870              None        NaN
# 4  -11.0 -20.263054              None        NaN
# 5    0.8   1.426456  ideal_function_2   0.532222
# 6   14.0  -0.066506  ideal_function_4   0.134233
# 7  -10.4  -2.007094              None        NaN
# 8  -15.0  -0.205363  ideal_function_4   0.452371
# 9    5.8  10.711373  ideal_function_2   0.656326
# 10  -7.6 -39.495400              None        NaN
# 11 -19.8 -19.915014  ideal_function_3   0.115014

# %% [markdown]
# ### Task- 1.1.3 : Data Visualization

# %%
from bokeh.plotting import figure, show, output_file
from bokeh.models import ColumnDataSource, Legend
from bokeh.layouts import gridplot

# %%
class BokehVisualizer:
    def __init__(self, train_data, test_data, chosen_ideal_functions, mapped_results):
        """
        Initialize the visualizer with data.

        :param train_data: DataFrame containing training data.
        :param test_data: DataFrame containing test data.
        :param chosen_ideal_functions: List of DataFrames for the chosen ideal functions.
        :param mapped_results: DataFrame containing mapped test data with deviations.
        """
        self.train_data = train_data
        self.test_data = test_data
        self.chosen_ideal_functions = chosen_ideal_functions
        self.mapped_results = mapped_results

    def plot_training_vs_ideal(self):
        """
        Plot training data and its corresponding ideal functions using Bokeh.
        """
        plots = []

        for i, col in enumerate(self.train_data.columns[1:], start=1):
            p = figure(title=f"Training Data vs Ideal Function {i}", 
                       x_axis_label='x', y_axis_label='y', 
                       plot_width=500, plot_height=400)
            
            p.scatter(self.train_data['x'], self.train_data[col], size=8, color="blue", legend_label=f"Training y{i}")
            
            ideal_func = self.chosen_ideal_functions[i - 1]
            p.line(ideal_func['x'], ideal_func['y'], line_width=2, color="red", legend_label=f"Ideal Function {i}")
            
            p.legend.location = "top_left"
            p.legend.title = "Legend"
            plots.append(p)

        grid = gridplot([plots[:2], plots[2:]])  
        output_file("training_vs_ideal.html")
        show(grid)

    def plot_test_mappings(self):
        """
        Plot test data and its mappings to ideal functions using Bokeh.
        """
        p = figure(title="Test Data Mappings to Ideal Functions", 
                   x_axis_label='x', y_axis_label='y', 
                   plot_width=800, plot_height=500)
        
        colors = ["red", "green", "blue", "purple"]

        for i, ideal_func in enumerate(self.chosen_ideal_functions):
            p.line(ideal_func['x'], ideal_func['y'], line_width=2, color=colors[i], legend_label=f"Ideal Function {i + 1}")

        source = ColumnDataSource(self.mapped_results)
        p.scatter(x="x", y="y", size=10, color="orange", source=source, legend_label="Test Data")

        p.legend.location = "top_left"
        p.legend.title = "Legend"

        output_file("test_data_mappings.html")
        show(p)

# %%
visualizer = BokehVisualizer(train_data, test_data, chosen_ideal_functions, mapped_results)

# %%
visualizer.plot_training_vs_ideal()

# %%
visualizer.plot_test_mappings()

# %% [markdown]
# ### Task- 1.1.4 : Unit Test

# %%
import unittest
from io import StringIO

# %%
train_csv = """x,y1,y2,y3,y4
-20,39.778572,-40.07859,-20.214268,-0.32491425
-19.9,39.604813,-39.784,-20.07095,-0.058819864
-19.8,40.09907,-40.018845,-19.906782,-0.4518296
"""
test_csv = """x,y
17.5,34.16104
0.3,1.2151024
-8.7,-16.843908
"""
ideal_csv = """x,y1,y2,y3,y4
-20,-0.9129453,0.40808207,9.087055,5.408082
-19.9,-0.8676441,0.4971858,9.132356,5.4971857
-19.8,-0.8390715,0.81616414,9.094273,5.589018
"""

# %%
train_data = pd.read_csv(StringIO(train_csv))
test_data = pd.read_csv(StringIO(test_csv))
ideal_data = pd.read_csv(StringIO(ideal_csv))

# %%
class TestIdealFunctionSelector(unittest.TestCase):
    def test_select_ideal_functions(self):
        from __main__ import IdealFunctionSelector  
        selector = IdealFunctionSelector(train_data, ideal_data)
        selected_functions, max_deviations = selector.select_ideal_functions()
        
        self.assertEqual(len(selected_functions), 4)
        
        self.assertIsInstance(selected_functions, list)
        self.assertIsInstance(max_deviations, list)
        
        self.assertTrue(all(dev >= 0 for dev in max_deviations))

# %%
class TestIdealFunctionMapper(unittest.TestCase):
    def test_map_test_data(self):
        from __main__ import IdealFunctionMapper  
        
        selected_ideal_functions = [
            ideal_data[['x', 'y1']].rename(columns={'y1': 'y'}),
            ideal_data[['x', 'y2']].rename(columns={'y2': 'y'}),
            ideal_data[['x', 'y3']].rename(columns={'y3': 'y'}),
            ideal_data[['x', 'y4']].rename(columns={'y4': 'y'}),
        ]
        max_deviations = [1.0, 1.2, 2.0, 0.8]
        
        mapper = IdealFunctionMapper(selected_ideal_functions, max_deviations)
        mapped_results = mapper.map_test_data(test_data)
        
        self.assertEqual(len(mapped_results), len(test_data))
        
        valid_functions = {f"ideal_function_{i+1}" for i in range(len(selected_ideal_functions))}
        self.assertTrue(all(
            row['mapped_function'] in valid_functions or pd.isna(row['mapped_function'])
            for _, row in mapped_results.iterrows()
        ))

# %%
class TestBokehVisualizer(unittest.TestCase):
    def test_visualization(self):
        from __main__ import BokehVisualizer  
        
        visualizer = BokehVisualizer(train_data, test_data, [
            ideal_data[['x', 'y1']].rename(columns={'y1': 'y'}),
            ideal_data[['x', 'y2']].rename(columns={'y2': 'y'}),
            ideal_data[['x', 'y3']].rename(columns={'y3': 'y'}),
            ideal_data[['x', 'y4']].rename(columns={'y4': 'y'}),
        ], pd.DataFrame({
            'x': test_data['x'],
            'y': test_data['y'],
            'mapped_function': ['ideal_function_1', None, 'ideal_function_3'],
            'deviation': [0.1, None, 1.5],
        }))
        
        self.assertIsNotNone(visualizer)

# %%
unittest.main(argv=[''], verbosity=2, exit=False)
# Out:
# test_visualization (__main__.TestBokehVisualizer) ... ok
# test_map_test_data (__main__.TestIdealFunctionMapper) ... ok
# test_select_ideal_functions (__main__.TestIdealFunctionSelector) ... ok
#
# ----------------------------------------------------------------------
# Ran 3 tests in 0.022s
#
# OK

# %% [markdown]
# # Task- 1.2

# %%
import matplotlib.pyplot as plt
from sqlalchemy import create_engine, Column, Integer, Float
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker
from sqlalchemy.exc import IntegrityError

# %%
Base = declarative_base()

# %%
class TrainingData(Base):
    __tablename__ = 'training_data'
    id = Column(Integer, primary_key=True)
    x = Column(Float)
    y1 = Column(Float)
    y2 = Column(Float)
    y3 = Column(Float)
    y4 = Column(Float)

class IdealFunctions(Base):
    __tablename__ = 'ideal_functions'
    id = Column(Integer, primary_key=True)
    x = Column(Float)
    y1 = Column(Float)
    y2 = Column(Float)

class TestResults(Base):
    __tablename__ = 'test_results'
    id = Column(Integer, primary_key=True)
    x = Column(Float)
    y = Column(Float)
    delta_y = Column(Float)
    ideal_function_id = Column(Integer)

# %%
engine = create_engine('sqlite:///Functional_Test.db', echo=True)
Base.metadata.create_all(engine)
Session = sessionmaker(bind=engine)
session = Session()
# Out:
# 2025-01-20 18:09:58,050 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-01-20 18:09:58,053 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("training_data")
# 2025-01-20 18:09:58,054 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-01-20 18:09:58,056 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("training_data")
# 2025-01-20 18:09:58,057 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-01-20 18:09:58,058 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("ideal_functions")
# 2025-01-20 18:09:58,058 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-01-20 18:09:58,060 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("ideal_functions")
# 2025-01-20 18:09:58,061 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-01-20 18:09:58,062 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("test_results")
# 2025-01-20 18:09:58,063 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-01-20 18:09:58,065 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("test_results")
# 2025-01-20 18:09:58,066 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-01-20 18:09:58,072 INFO sqlalchemy.engine.Engine
# CREATE TABLE training_data (
# 	id INTEGER NOT NULL,
# 	x FLOAT,
# 	y1 FLOAT,
# 	y2 FLOAT,
# 	y3 FLOAT,
# 	y4 FLOAT,
# 	PRIMARY KEY (id)
# )
#
#
# 2025-01-20 18:09:58,074 INFO sqlalchemy.engine.Engine [no key 0.00188s] ()
# 2025-01-20 18:09:58,080 INFO sqlalchemy.engine.Engine
# CREATE TABLE ideal_functions (
# 	id INTEGER NOT NULL,
# 	x FLOAT,
# 	y1 FLOAT,
# 	y2 FLOAT,
# 	PRIMARY KEY (id)
# )
#
#
# 2025-01-20 18:09:58,081 INFO sqlalchemy.engine.Engine [no key 0.00099s] ()
# 2025-01-20 18:09:58,088 INFO sqlalchemy.engine.Engine
# CREATE TABLE test_results (
# 	id INTEGER NOT NULL,
# 	x FLOAT,
# 	y FLOAT,
# 	delta_y FLOAT,
# 	ideal_function_id INTEGER,
# 	PRIMARY KEY (id)
# )
#
#
# 2025-01-20 18:09:58,089 INFO sqlalchemy.engine.Engine [no key 0.00188s] ()
# 2025-01-20 18:09:58,095 INFO sqlalchemy.engine.Engine COMMIT

# %%
class DataProcessor:
    def __init__(self, session):
        self.session = session

    def load_data(self, file_path, data_type):
        """Generalized function to load different types of data."""
        df = pd.read_csv(file_path)
        for _, row in df.iterrows():
            if data_type == 'training':
                self.add_training_data(row)
            elif data_type == 'ideal':
                self.add_ideal_functions(row)
            elif data_type == 'test':
                self.add_test_data(row)
        self.session.commit()

    def add_training_data(self, row):
        """Insert training data."""
        try:
            self.session.add(TrainingData(x=row['x'], y1=row['y1'], y2=row['y2'], y3=row['y3'], y4=row['y4']))
        except IntegrityError as e:
            print(f"Error inserting training data: {e}")

    def add_ideal_functions(self, row):
        """Insert ideal functions."""
        try:
            self.session.add(IdealFunctions(x=row['x'], y1=row['y1'], y2=row['y2']))
        except IntegrityError as e:
            print(f"Error inserting ideal function: {e}")

    def add_test_data(self, row):
        """Insert test data and calculate deviations."""
        ideal_function_id = self.get_best_match_for_test(row['x'])
        ideal_y = self.get_ideal_y_for_function(ideal_function_id, row['x'])
        delta_y = abs(row['y'] - ideal_y)
        try:
            self.session.add(TestResults(x=row['x'], y=row['y'], delta_y=delta_y, ideal_function_id=ideal_function_id))
        except IntegrityError as e:
            print(f"Error inserting test result: {e}")

    def get_best_match_for_test(self, x_value):
        """Select the ideal function that best matches the test point."""
        return 1  

    def get_ideal_y_for_function(self, ideal_function_id, x_value):
        """Fetch the ideal y value for a given x value."""
        ideal_function = self.session.query(IdealFunctions).filter_by(x=x_value).first()
        if ideal_function:
            return getattr(ideal_function, f'y{ideal_function_id}')
        else:
            raise ValueError(f"No ideal function found for x={x_value}")

    def visualize_results(self):
        """Visualize test results using matplotlib."""
        results = self.session.query(TestResults).all()
        x_vals = [result.x for result in results]
        delta_y_vals = [result.delta_y for result in results]

        plt.figure(figsize=(10, 6))
        plt.scatter(x_vals, delta_y_vals, color='b', label='Delta Y')
        plt.title('Test Results: Delta Y vs. X')
        plt.xlabel('X')
        plt.ylabel('Delta Y')
        plt.grid(True)
        plt.legend()
        plt.show()

# %%
if __name__ == "__main__":
    processor = DataProcessor(session)
    
    processor.load_data('train.csv', 'training')
    processor.load_data('ideal.csv', 'ideal')
    processor.load_data('test.csv', 'test')
    
    processor.visualize_results()
# Out:
# 2025-01-20 18:10:10,071 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-01-20 18:10:10,081 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,081 INFO sqlalchemy.engine.Engine [generated in 0.00099s] (-20.0, 39.778572, -40.07859, -20.214268, -0.32491425)
# 2025-01-20 18:10:10,084 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,086 INFO sqlalchemy.engine.Engine [cached since 0.005235s ago] (-19.9, 39.604813, -39.784, -20.07095, -0.058819864)
# 2025-01-20 18:10:10,087 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,088 INFO sqlalchemy.engine.Engine [cached since 0.007738s ago] (-19.8, 40.09907, -40.018845, -19.906782, -0.4518296)
# 2025-01-20 18:10:10,090 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,092 INFO sqlalchemy.engine.Engine [cached since 0.01137s ago] (-19.7, 40.1511, -39.518402, -19.389118, -0.6120442)
# 2025-01-20 18:10:10,093 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,095 INFO sqlalchemy.engine.Engine [cached since 0.01485s ago] (-19.6, 39.795662, -39.360065, -19.81589, -0.3060756)
# 2025-01-20 18:10:10,097 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,098 INFO sqlalchemy.engine.Engine [cached since 0.01718s ago] (-19.5, 39.340855, -38.90581, -19.287113, -0.062154666)
# 2025-01-20 18:10:10,100 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,102 INFO sqlalchemy.engine.Engine [cached since 0.02157s ago] (-19.4, 39.25246, -39.12036, -19.683708, 0.026392838)
# 2025-01-20 18:10:10,104 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,106 INFO sqlalchemy.engine.Engine [cached since 0.02549s ago] (-19.3, 38.590164, -38.62107, -19.494537, -0.2690418)
# 2025-01-20 18:10:10,107 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,108 INFO sqlalchemy.engine.Engine [cached since 0.02747s ago] (-19.2, 38.893463, -38.806778, -19.533716, 0.08567329)
# 2025-01-20 18:10:10,110 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,110 INFO sqlalchemy.engine.Engine [cached since 0.0299s ago] (-19.1, 38.364567, -38.354656, -18.75372, -0.29954198)
# 2025-01-20 18:10:10,114 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,115 INFO sqlalchemy.engine.Engine [cached since 0.03444s ago] (-19.0, 38.13553, -37.795067, -19.363068, -0.553223)
# 2025-01-20 18:10:10,116 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,118 INFO sqlalchemy.engine.Engine [cached since 0.03723s ago] (-18.9, 37.825813, -37.984848, -18.528309, 0.040018722)
# 2025-01-20 18:10:10,123 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,124 INFO sqlalchemy.engine.Engine [cached since 0.04376s ago] (-18.8, 37.672874, -37.855568, -18.92033, 0.0705662)
# 2025-01-20 18:10:10,126 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,128 INFO sqlalchemy.engine.Engine [cached since 0.04754s ago] (-18.7, 37.99707, -37.64723, -18.858202, 0.09534555)
# 2025-01-20 18:10:10,130 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,131 INFO sqlalchemy.engine.Engine [cached since 0.05041s ago] (-18.6, 37.38134, -37.436577, -18.457552, -0.3021374)
# 2025-01-20 18:10:10,132 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,133 INFO sqlalchemy.engine.Engine [cached since 0.05219s ago] (-18.5, 37.429653, -37.083054, -18.551897, -0.0018355072)
# 2025-01-20 18:10:10,135 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,137 INFO sqlalchemy.engine.Engine [cached since 0.05621s ago] (-18.4, 37.330147, -36.65041, -18.406178, 0.34796613)
# 2025-01-20 18:10:10,138 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,140 INFO sqlalchemy.engine.Engine [cached since 0.05966s ago] (-18.3, 36.635334, -36.5591, -18.573486, 0.08883932)
# 2025-01-20 18:10:10,141 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,142 INFO sqlalchemy.engine.Engine [cached since 0.06133s ago] (-18.2, 36.31057, -35.691395, -18.298632, -0.15387341)
# 2025-01-20 18:10:10,143 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,143 INFO sqlalchemy.engine.Engine [cached since 0.06293s ago] (-18.1, 36.379223, -35.42202, -17.694733, 0.6145841)
# 2025-01-20 18:10:10,146 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,146 INFO sqlalchemy.engine.Engine [cached since 0.06607s ago] (-18.0, 36.74498, -35.771496, -18.15217, 0.38540468)
# 2025-01-20 18:10:10,148 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,148 INFO sqlalchemy.engine.Engine [cached since 0.06799s ago] (-17.9, 35.609684, -35.880722, -18.224195, -0.20963566)
# 2025-01-20 18:10:10,150 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,152 INFO sqlalchemy.engine.Engine [cached since 0.07122s ago] (-17.8, 35.421272, -35.432663, -17.929127, -0.08499361)
# 2025-01-20 18:10:10,154 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,156 INFO sqlalchemy.engine.Engine [cached since 0.07546s ago] (-17.7, 35.902496, -35.311367, -17.453093, 0.20769778)
# 2025-01-20 18:10:10,158 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,158 INFO sqlalchemy.engine.Engine [cached since 0.07783s ago] (-17.6, 35.009613, -35.05815, -18.051992, -0.14993647)
# 2025-01-20 18:10:10,159 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,160 INFO sqlalchemy.engine.Engine [cached since 0.07938s ago] (-17.5, 35.37503, -34.652325, -17.750078, -0.11715304)
# 2025-01-20 18:10:10,161 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,162 INFO sqlalchemy.engine.Engine [cached since 0.08109s ago] (-17.4, 34.673225, -34.403038, -17.254086, 0.2630343)
# 2025-01-20 18:10:10,163 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,163 INFO sqlalchemy.engine.Engine [cached since 0.08288s ago] (-17.3, 34.73963, -34.438858, -17.680382, -0.3331845)
# 2025-01-20 18:10:10,164 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,165 INFO sqlalchemy.engine.Engine [cached since 0.08428s ago] (-17.2, 34.099274, -33.4363, -17.28941, -0.14619163)
# 2025-01-20 18:10:10,166 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,166 INFO sqlalchemy.engine.Engine [cached since 0.08571s ago] (-17.1, 34.380894, -33.81982, -17.085196, 0.34196478)
# 2025-01-20 18:10:10,167 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,167 INFO sqlalchemy.engine.Engine [cached since 0.08705s ago] (-17.0, 33.614796, -33.146416, -16.69206, -0.113865964)
# 2025-01-20 18:10:10,168 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,170 INFO sqlalchemy.engine.Engine [cached since 0.08964s ago] (-16.9, 33.971043, -33.033516, -16.62859, -0.2902285)
# 2025-01-20 18:10:10,172 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,172 INFO sqlalchemy.engine.Engine [cached since 0.09196s ago] (-16.8, 33.07349, -33.12445, -16.603662, -0.6693005)
# 2025-01-20 18:10:10,173 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,174 INFO sqlalchemy.engine.Engine [cached since 0.09382s ago] (-16.7, 33.003006, -33.15249, -16.823805, -0.11059754)
# 2025-01-20 18:10:10,175 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,176 INFO sqlalchemy.engine.Engine [cached since 0.09535s ago] (-16.6, 32.82969, -32.514786, -16.207123, 0.13672218)
# 2025-01-20 18:10:10,177 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,177 INFO sqlalchemy.engine.Engine [cached since 0.09676s ago] (-16.5, 32.27977, -33.125202, -16.162659, 0.10311103)
# 2025-01-20 18:10:10,178 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,179 INFO sqlalchemy.engine.Engine [cached since 0.09836s ago] (-16.4, 32.51663, -32.68559, -16.269371, -0.011137535)
# 2025-01-20 18:10:10,180 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,180 INFO sqlalchemy.engine.Engine [cached since 0.0999s ago] (-16.3, 32.194664, -32.186275, -16.139305, 0.23491701)
# 2025-01-20 18:10:10,181 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,183 INFO sqlalchemy.engine.Engine [cached since 0.1023s ago] (-16.2, 31.744162, -32.208416, -16.36914, 0.10328723)
# 2025-01-20 18:10:10,184 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,185 INFO sqlalchemy.engine.Engine [cached since 0.1042s ago] (-16.1, 31.290579, -32.393738, -15.604486, -0.14163977)
# 2025-01-20 18:10:10,188 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,189 INFO sqlalchemy.engine.Engine [cached since 0.1082s ago] (-16.0, 31.541817, -31.90914, -16.16006, -0.5188936)
# 2025-01-20 18:10:10,190 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,192 INFO sqlalchemy.engine.Engine [cached since 0.1111s ago] (-15.9, 31.377129, -31.849277, -15.54072, 0.083608545)
# 2025-01-20 18:10:10,193 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,194 INFO sqlalchemy.engine.Engine [cached since 0.1135s ago] (-15.8, 31.465273, -31.789133, -15.530875, -0.0038458784)
# 2025-01-20 18:10:10,195 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,196 INFO sqlalchemy.engine.Engine [cached since 0.1155s ago] (-15.7, 30.581562, -31.266651, -16.140867, -0.3180933)
# 2025-01-20 18:10:10,197 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,198 INFO sqlalchemy.engine.Engine [cached since 0.1172s ago] (-15.6, 30.277567, -31.492805, -15.58734, -0.08732379)
# 2025-01-20 18:10:10,199 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,199 INFO sqlalchemy.engine.Engine [cached since 0.1187s ago] (-15.5, 30.291279, -31.408848, -15.601471, 0.44567823)
# 2025-01-20 18:10:10,200 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,201 INFO sqlalchemy.engine.Engine [cached since 0.1209s ago] (-15.4, 30.506998, -31.34851, -15.176161, 0.022070993)
# 2025-01-20 18:10:10,203 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,204 INFO sqlalchemy.engine.Engine [cached since 0.1231s ago] (-15.3, 30.038458, -30.641222, -15.519996, 0.09844557)
# 2025-01-20 18:10:10,205 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,206 INFO sqlalchemy.engine.Engine [cached since 0.1252s ago] (-15.2, 30.419271, -30.306372, -15.377739, -0.06104431)
# 2025-01-20 18:10:10,207 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,207 INFO sqlalchemy.engine.Engine [cached since 0.1268s ago] (-15.1, 29.629843, -30.895721, -15.373958, 0.39804256)
# 2025-01-20 18:10:10,208 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,209 INFO sqlalchemy.engine.Engine [cached since 0.1282s ago] (-15.0, 29.853884, -30.701433, -15.476767, 0.51364607)
# 2025-01-20 18:10:10,210 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,210 INFO sqlalchemy.engine.Engine [cached since 0.1297s ago] (-14.9, 29.217709, -30.033648, -14.589854, 0.24456862)
# 2025-01-20 18:10:10,211 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,212 INFO sqlalchemy.engine.Engine [cached since 0.1317s ago] (-14.8, 29.09884, -29.696539, -14.819253, 0.48858148)
# 2025-01-20 18:10:10,213 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,214 INFO sqlalchemy.engine.Engine [cached since 0.1335s ago] (-14.7, 28.667645, -29.410593, -14.359352, -0.1469725)
# 2025-01-20 18:10:10,215 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,215 INFO sqlalchemy.engine.Engine [cached since 0.1348s ago] (-14.6, 28.79126, -29.465576, -14.203665, 0.042427503)
# 2025-01-20 18:10:10,216 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,217 INFO sqlalchemy.engine.Engine [cached since 0.1364s ago] (-14.5, 28.435364, -29.353567, -14.059407, 0.11133349)
# 2025-01-20 18:10:10,218 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,221 INFO sqlalchemy.engine.Engine [cached since 0.1406s ago] (-14.4, 28.961216, -28.957647, -14.142215, 0.38398743)
# 2025-01-20 18:10:10,222 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,223 INFO sqlalchemy.engine.Engine [cached since 0.1427s ago] (-14.3, 28.921854, -29.341013, -14.107099, 0.294356)
# 2025-01-20 18:10:10,225 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,226 INFO sqlalchemy.engine.Engine [cached since 0.1451s ago] (-14.2, 28.232948, -28.592756, -14.505439, -0.37056503)
# 2025-01-20 18:10:10,227 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,230 INFO sqlalchemy.engine.Engine [cached since 0.149s ago] (-14.1, 28.210249, -29.126505, -14.419173, 0.02287512)
# 2025-01-20 18:10:10,231 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,232 INFO sqlalchemy.engine.Engine [cached since 0.1511s ago] (-14.0, 28.152843, -28.66428, -14.1337805, -0.27583477)
# 2025-01-20 18:10:10,233 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,234 INFO sqlalchemy.engine.Engine [cached since 0.1527s ago] (-13.9, 27.976458, -27.830526, -14.347666, -0.048467655)
# 2025-01-20 18:10:10,234 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,236 INFO sqlalchemy.engine.Engine [cached since 0.1553s ago] (-13.8, 27.49858, -27.606556, -13.959812, -0.06256741)
# 2025-01-20 18:10:10,238 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,238 INFO sqlalchemy.engine.Engine [cached since 0.1575s ago] (-13.7, 27.319183, -27.805117, -13.305638, -0.6818926)
# 2025-01-20 18:10:10,240 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,241 INFO sqlalchemy.engine.Engine [cached since 0.16s ago] (-13.6, 26.959885, -27.46691, -13.460358, -0.35765544)
# 2025-01-20 18:10:10,242 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,242 INFO sqlalchemy.engine.Engine [cached since 0.1615s ago] (-13.5, 27.010479, -27.046322, -13.545402, -0.050601155)
# 2025-01-20 18:10:10,243 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,244 INFO sqlalchemy.engine.Engine [cached since 0.1629s ago] (-13.4, 27.444553, -27.415642, -13.1895275, -0.6999692)
# 2025-01-20 18:10:10,245 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,245 INFO sqlalchemy.engine.Engine [cached since 0.1645s ago] (-13.3, 26.477736, -26.918652, -13.590001, 0.22568727)
# 2025-01-20 18:10:10,247 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,248 INFO sqlalchemy.engine.Engine [cached since 0.1665s ago] (-13.2, 27.011068, -27.134518, -13.620864, -0.65312505)
# 2025-01-20 18:10:10,249 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,250 INFO sqlalchemy.engine.Engine [cached since 0.1687s ago] (-13.1, 26.715807, -26.272911, -13.044477, 0.031488232)
# 2025-01-20 18:10:10,254 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,255 INFO sqlalchemy.engine.Engine [cached since 0.1741s ago] (-13.0, 26.56426, -26.450706, -12.866318, 0.30753955)
# 2025-01-20 18:10:10,256 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,257 INFO sqlalchemy.engine.Engine [cached since 0.1763s ago] (-12.9, 25.957773, -26.156477, -12.878518, 0.1487716)
# 2025-01-20 18:10:10,259 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,260 INFO sqlalchemy.engine.Engine [cached since 0.1789s ago] (-12.8, 25.722597, -25.995968, -12.422428, -0.492448)
# 2025-01-20 18:10:10,261 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,261 INFO sqlalchemy.engine.Engine [cached since 0.1802s ago] (-12.7, 25.730907, -25.139296, -13.033004, 0.051321585)
# 2025-01-20 18:10:10,262 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,263 INFO sqlalchemy.engine.Engine [cached since 0.182s ago] (-12.6, 25.571356, -25.608099, -12.2511425, 0.3909315)
# 2025-01-20 18:10:10,264 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,264 INFO sqlalchemy.engine.Engine [cached since 0.1834s ago] (-12.5, 25.54436, -25.107195, -12.507834, -0.17399704)
# 2025-01-20 18:10:10,265 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,266 INFO sqlalchemy.engine.Engine [cached since 0.1849s ago] (-12.4, 25.1135, -24.686323, -12.226825, 0.027632099)
# 2025-01-20 18:10:10,267 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,268 INFO sqlalchemy.engine.Engine [cached since 0.1865s ago] (-12.3, 25.348244, -24.475128, -11.995999, 0.1656311)
# 2025-01-20 18:10:10,268 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,271 INFO sqlalchemy.engine.Engine [cached since 0.1902s ago] (-12.2, 24.936493, -24.30999, -12.45788, 0.1577437)
# 2025-01-20 18:10:10,272 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,273 INFO sqlalchemy.engine.Engine [cached since 0.1922s ago] (-12.1, 25.083504, -23.531492, -12.261272, -0.0016530884)
# 2025-01-20 18:10:10,274 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,275 INFO sqlalchemy.engine.Engine [cached since 0.1939s ago] (-12.0, 24.11862, -23.903694, -11.718515, 0.3499292)
# 2025-01-20 18:10:10,277 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,277 INFO sqlalchemy.engine.Engine [cached since 0.1962s ago] (-11.9, 24.248436, -23.587065, -11.686815, 0.41648862)
# 2025-01-20 18:10:10,278 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,280 INFO sqlalchemy.engine.Engine [cached since 0.1992s ago] (-11.8, 24.016615, -23.546015, -11.714512, 0.66258484)
# 2025-01-20 18:10:10,281 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,282 INFO sqlalchemy.engine.Engine [cached since 0.2008s ago] (-11.7, 23.320929, -22.805626, -12.198936, -0.02240543)
# 2025-01-20 18:10:10,283 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,285 INFO sqlalchemy.engine.Engine [cached since 0.2035s ago] (-11.6, 23.880903, -22.600348, -11.964934, -0.03453156)
# 2025-01-20 18:10:10,286 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,287 INFO sqlalchemy.engine.Engine [cached since 0.2058s ago] (-11.5, 23.497711, -22.521463, -11.5062065, 0.5677128)
# 2025-01-20 18:10:10,289 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,290 INFO sqlalchemy.engine.Engine [cached since 0.2093s ago] (-11.4, 23.424501, -22.17204, -11.757312, -0.3188679)
# 2025-01-20 18:10:10,291 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,292 INFO sqlalchemy.engine.Engine [cached since 0.2111s ago] (-11.3, 22.485634, -21.810442, -11.082408, 0.119056836)
# 2025-01-20 18:10:10,293 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,293 INFO sqlalchemy.engine.Engine [cached since 0.2124s ago] (-11.2, 22.158628, -21.716888, -11.555117, -0.34085307)
# 2025-01-20 18:10:10,294 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,295 INFO sqlalchemy.engine.Engine [cached since 0.2138s ago] (-11.1, 22.532522, -21.403929, -10.899252, 0.21685402)
# 2025-01-20 18:10:10,296 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,297 INFO sqlalchemy.engine.Engine [cached since 0.2156s ago] (-11.0, 22.341274, -21.440613, -10.796314, 0.22407265)
# 2025-01-20 18:10:10,298 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,298 INFO sqlalchemy.engine.Engine [cached since 0.2174s ago] (-10.9, 21.529554, -21.288595, -10.905359, -0.24584216)
# 2025-01-20 18:10:10,300 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,301 INFO sqlalchemy.engine.Engine [cached since 0.2198s ago] (-10.8, 21.09595, -21.535612, -10.97698, -0.57189953)
# 2025-01-20 18:10:10,302 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,303 INFO sqlalchemy.engine.Engine [cached since 0.2221s ago] (-10.7, 21.697912, -21.374477, -10.89252, -0.047246568)
# 2025-01-20 18:10:10,304 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,305 INFO sqlalchemy.engine.Engine [cached since 0.2242s ago] (-10.6, 20.96303, -20.33526, -10.124289, 0.1746914)
# 2025-01-20 18:10:10,306 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,307 INFO sqlalchemy.engine.Engine [cached since 0.226s ago] (-10.5, 21.038134, -20.26395, -10.852309, -0.31222168)
# 2025-01-20 18:10:10,307 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,308 INFO sqlalchemy.engine.Engine [cached since 0.2274s ago] (-10.4, 20.243206, -20.050976, -10.682611, -0.36040372)
# 2025-01-20 18:10:10,309 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,310 INFO sqlalchemy.engine.Engine [cached since 0.2289s ago] (-10.3, 20.255909, -20.585495, -9.98029, -0.18458326)
# 2025-01-20 18:10:10,311 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,311 INFO sqlalchemy.engine.Engine [cached since 0.2305s ago] (-10.2, 19.582912, -19.752676, -10.475182, -0.43359447)
# 2025-01-20 18:10:10,312 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,313 INFO sqlalchemy.engine.Engine [cached since 0.2326s ago] (-10.1, 19.370066, -19.482843, -9.706017, -0.080372296)
# 2025-01-20 18:10:10,314 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,315 INFO sqlalchemy.engine.Engine [cached since 0.2344s ago] (-10.0, 20.072577, -19.489513, -10.058358, 0.24360992)
# 2025-01-20 18:10:10,316 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,318 INFO sqlalchemy.engine.Engine [cached since 0.2375s ago] (-9.9, 19.6761, -19.831825, -9.661298, -0.13811694)
# 2025-01-20 18:10:10,320 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,321 INFO sqlalchemy.engine.Engine [cached since 0.2406s ago] (-9.8, 19.284739, -19.574781, -9.431196, 0.28410357)
# 2025-01-20 18:10:10,322 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,323 INFO sqlalchemy.engine.Engine [cached since 0.2423s ago] (-9.7, 19.058212, -18.926718, -9.263311, -0.39468098)
# 2025-01-20 18:10:10,324 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,325 INFO sqlalchemy.engine.Engine [cached since 0.2445s ago] (-9.6, 19.146034, -19.605854, -10.092775, -0.11615117)
# 2025-01-20 18:10:10,326 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,327 INFO sqlalchemy.engine.Engine [cached since 0.2459s ago] (-9.5, 18.636082, -18.725649, -9.194448, 0.057054125)
# 2025-01-20 18:10:10,328 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,330 INFO sqlalchemy.engine.Engine [cached since 0.2489s ago] (-9.4, 18.330507, -18.767792, -9.26504, 0.34872243)
# 2025-01-20 18:10:10,331 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,332 INFO sqlalchemy.engine.Engine [cached since 0.2508s ago] (-9.3, 18.04734, -19.009575, -9.648047, 0.41504073)
# 2025-01-20 18:10:10,333 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,334 INFO sqlalchemy.engine.Engine [cached since 0.2529s ago] (-9.2, 17.831709, -18.887852, -9.356181, -0.2593116)
# 2025-01-20 18:10:10,335 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,336 INFO sqlalchemy.engine.Engine [cached since 0.2549s ago] (-9.1, 18.091381, -18.2001, -8.984978, 0.22550505)
# 2025-01-20 18:10:10,337 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,338 INFO sqlalchemy.engine.Engine [cached since 0.2565s ago] (-9.0, 17.279009, -18.00246, -8.69369, 0.24083145)
# 2025-01-20 18:10:10,339 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,339 INFO sqlalchemy.engine.Engine [cached since 0.258s ago] (-8.9, 17.799309, -17.802477, -8.641598, 0.7065497)
# 2025-01-20 18:10:10,340 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,341 INFO sqlalchemy.engine.Engine [cached since 0.2596s ago] (-8.8, 17.383955, -18.00152, -8.927293, -0.19034003)
# 2025-01-20 18:10:10,342 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,342 INFO sqlalchemy.engine.Engine [cached since 0.2611s ago] (-8.7, 16.597107, -17.40592, -8.726125, 0.23579614)
# 2025-01-20 18:10:10,343 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,344 INFO sqlalchemy.engine.Engine [cached since 0.2625s ago] (-8.6, 16.546343, -17.703665, -8.885028, 0.33037788)
# 2025-01-20 18:10:10,344 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,345 INFO sqlalchemy.engine.Engine [cached since 0.2639s ago] (-8.5, 17.167364, -17.752602, -8.30539, 0.33593923)
# 2025-01-20 18:10:10,346 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,347 INFO sqlalchemy.engine.Engine [cached since 0.2659s ago] (-8.4, 16.093102, -16.918701, -8.525435, 0.11099869)
# 2025-01-20 18:10:10,348 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,349 INFO sqlalchemy.engine.Engine [cached since 0.2675s ago] (-8.3, 16.103878, -16.877802, -8.572217, -0.0810489)
# 2025-01-20 18:10:10,350 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,350 INFO sqlalchemy.engine.Engine [cached since 0.2692s ago] (-8.2, 15.746574, -16.957348, -8.436194, 0.07858246)
# 2025-01-20 18:10:10,352 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,354 INFO sqlalchemy.engine.Engine [cached since 0.2727s ago] (-8.1, 15.582306, -16.944826, -7.82068, 0.036169287)
# 2025-01-20 18:10:10,355 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,357 INFO sqlalchemy.engine.Engine [cached since 0.2752s ago] (-8.0, 16.414562, -16.00641, -7.6288624, 0.5662069)
# 2025-01-20 18:10:10,358 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,358 INFO sqlalchemy.engine.Engine [cached since 0.2771s ago] (-7.9, 16.137983, -15.991172, -8.225133, -0.2316124)
# 2025-01-20 18:10:10,359 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,360 INFO sqlalchemy.engine.Engine [cached since 0.2785s ago] (-7.8, 15.229189, -15.626455, -7.968554, 0.44375187)
# 2025-01-20 18:10:10,361 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,361 INFO sqlalchemy.engine.Engine [cached since 0.2801s ago] (-7.7, 15.616413, -15.665973, -7.7632246, -0.18302464)
# 2025-01-20 18:10:10,362 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,363 INFO sqlalchemy.engine.Engine [cached since 0.2821s ago] (-7.6, 15.097614, -16.081308, -7.2120543, 0.010636473)
# 2025-01-20 18:10:10,365 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,366 INFO sqlalchemy.engine.Engine [cached since 0.2849s ago] (-7.5, 15.170431, -15.791869, -7.5496445, -0.6327828)
# 2025-01-20 18:10:10,367 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,368 INFO sqlalchemy.engine.Engine [cached since 0.2871s ago] (-7.4, 14.878976, -15.018995, -7.328601, -0.1484294)
# 2025-01-20 18:10:10,370 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,371 INFO sqlalchemy.engine.Engine [cached since 0.2893s ago] (-7.3, 14.421107, -15.070971, -7.6536365, -0.1061275)
# 2025-01-20 18:10:10,371 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,372 INFO sqlalchemy.engine.Engine [cached since 0.291s ago] (-7.2, 14.863264, -14.749033, -6.8203835, -0.20960827)
# 2025-01-20 18:10:10,373 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,374 INFO sqlalchemy.engine.Engine [cached since 0.2929s ago] (-7.1, 14.070099, -14.674672, -7.492106, -0.45676327)
# 2025-01-20 18:10:10,375 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,376 INFO sqlalchemy.engine.Engine [cached since 0.2944s ago] (-7.0, 14.589213, -14.497041, -7.154825, -0.06690998)
# 2025-01-20 18:10:10,377 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,377 INFO sqlalchemy.engine.Engine [cached since 0.2961s ago] (-6.9, 13.72398, -13.691697, -6.480628, 0.26347908)
# 2025-01-20 18:10:10,378 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,379 INFO sqlalchemy.engine.Engine [cached since 0.2978s ago] (-6.8, 14.393147, -13.8938265, -6.9007196, -0.019564947)
# 2025-01-20 18:10:10,381 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,382 INFO sqlalchemy.engine.Engine [cached since 0.3008s ago] (-6.7, 13.849966, -13.1873455, -6.839167, -0.44084644)
# 2025-01-20 18:10:10,383 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,385 INFO sqlalchemy.engine.Engine [cached since 0.3033s ago] (-6.6, 14.021013, -13.8100815, -6.740013, -0.5409074)
# 2025-01-20 18:10:10,387 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,388 INFO sqlalchemy.engine.Engine [cached since 0.3072s ago] (-6.5, 13.683014, -13.57312, -6.343632, -0.13636306)
# 2025-01-20 18:10:10,390 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,390 INFO sqlalchemy.engine.Engine [cached since 0.3093s ago] (-6.4, 13.447332, -12.517593, -6.2333894, -0.16058826)
# 2025-01-20 18:10:10,391 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,392 INFO sqlalchemy.engine.Engine [cached since 0.3107s ago] (-6.3, 13.583929, -12.297417, -6.47137, -0.22272846)
# 2025-01-20 18:10:10,393 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,394 INFO sqlalchemy.engine.Engine [cached since 0.3123s ago] (-6.2, 12.84962, -12.0087805, -6.4169145, 0.14366315)
# 2025-01-20 18:10:10,395 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,395 INFO sqlalchemy.engine.Engine [cached since 0.3141s ago] (-6.1, 12.38746, -11.696795, -5.98529, -0.33892706)
# 2025-01-20 18:10:10,396 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,397 INFO sqlalchemy.engine.Engine [cached since 0.3161s ago] (-6.0, 12.770117, -11.887695, -5.5694, 0.6109282)
# 2025-01-20 18:10:10,398 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,399 INFO sqlalchemy.engine.Engine [cached since 0.3178s ago] (-5.9, 12.19691, -11.479572, -6.3188567, 0.36211476)
# 2025-01-20 18:10:10,401 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,402 INFO sqlalchemy.engine.Engine [cached since 0.3209s ago] (-5.8, 11.574714, -11.649666, -5.5815163, 0.40015438)
# 2025-01-20 18:10:10,403 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,404 INFO sqlalchemy.engine.Engine [cached since 0.3231s ago] (-5.7, 11.610783, -10.886972, -5.7935023, 0.59391856)
# 2025-01-20 18:10:10,405 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,406 INFO sqlalchemy.engine.Engine [cached since 0.3248s ago] (-5.6, 11.190752, -11.336878, -5.8103137, 0.13259691)
# 2025-01-20 18:10:10,407 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,408 INFO sqlalchemy.engine.Engine [cached since 0.3266s ago] (-5.5, 11.671036, -11.127859, -5.3072863, 0.41284594)
# 2025-01-20 18:10:10,409 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,409 INFO sqlalchemy.engine.Engine [cached since 0.3281s ago] (-5.4, 11.4051485, -10.1569605, -5.3916306, 0.09114355)
# 2025-01-20 18:10:10,410 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,411 INFO sqlalchemy.engine.Engine [cached since 0.3301s ago] (-5.3, 11.164489, -9.940487, -4.9274735, 0.5767008)
# 2025-01-20 18:10:10,413 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,414 INFO sqlalchemy.engine.Engine [cached since 0.3325s ago] (-5.2, 10.486, -9.530538, -4.9070063, -0.043267846)
# 2025-01-20 18:10:10,415 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,417 INFO sqlalchemy.engine.Engine [cached since 0.3354s ago] (-5.1, 10.649805, -9.756274, -5.2677565, 0.089222156)
# 2025-01-20 18:10:10,419 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,421 INFO sqlalchemy.engine.Engine [cached since 0.3394s ago] (-5.0, 10.522831, -9.092859, -4.8167667, 0.2228631)
# 2025-01-20 18:10:10,422 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,423 INFO sqlalchemy.engine.Engine [cached since 0.342s ago] (-4.9, 10.376054, -9.068665, -4.701068, 0.1488276)
# 2025-01-20 18:10:10,424 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,425 INFO sqlalchemy.engine.Engine [cached since 0.3435s ago] (-4.8, 9.381154, -9.035655, -5.270897, 0.12032644)
# 2025-01-20 18:10:10,425 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,426 INFO sqlalchemy.engine.Engine [cached since 0.3449s ago] (-4.7, 9.4822035, -9.037607, -4.420576, -0.12405812)
# 2025-01-20 18:10:10,428 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,428 INFO sqlalchemy.engine.Engine [cached since 0.3472s ago] (-4.6, 9.121017, -8.576267, -4.35842, -0.303996)
# 2025-01-20 18:10:10,432 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,433 INFO sqlalchemy.engine.Engine [cached since 0.352s ago] (-4.5, 8.4033785, -8.350241, -4.7953453, 0.017843474)
# 2025-01-20 18:10:10,434 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,435 INFO sqlalchemy.engine.Engine [cached since 0.3539s ago] (-4.4, 8.859767, -8.344224, -4.759984, 0.18434401)
# 2025-01-20 18:10:10,436 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,437 INFO sqlalchemy.engine.Engine [cached since 0.3561s ago] (-4.3, 7.954933, -8.244953, -3.8611631, 0.23242088)
# 2025-01-20 18:10:10,438 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,439 INFO sqlalchemy.engine.Engine [cached since 0.3579s ago] (-4.2, 8.573348, -7.755439, -4.392904, -0.009054876)
# 2025-01-20 18:10:10,440 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,441 INFO sqlalchemy.engine.Engine [cached since 0.3596s ago] (-4.1, 8.353645, -8.040879, -4.0032067, -0.20753747)
# 2025-01-20 18:10:10,442 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,443 INFO sqlalchemy.engine.Engine [cached since 0.3613s ago] (-4.0, 8.023236, -7.695794, -4.0911193, 0.08292602)
# 2025-01-20 18:10:10,443 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,444 INFO sqlalchemy.engine.Engine [cached since 0.363s ago] (-3.9, 7.614426, -7.2750063, -3.6341643, 0.24788724)
# 2025-01-20 18:10:10,445 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,447 INFO sqlalchemy.engine.Engine [cached since 0.3657s ago] (-3.8, 7.589857, -7.496997, -4.222018, -0.53544486)
# 2025-01-20 18:10:10,448 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,450 INFO sqlalchemy.engine.Engine [cached since 0.369s ago] (-3.7, 6.9436646, -6.8622985, -4.0255666, -0.072027445)
# 2025-01-20 18:10:10,453 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,455 INFO sqlalchemy.engine.Engine [cached since 0.3734s ago] (-3.6, 6.7658954, -7.168956, -3.423373, -0.39109442)
# 2025-01-20 18:10:10,456 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,457 INFO sqlalchemy.engine.Engine [cached since 0.3756s ago] (-3.5, 6.7666287, -6.8240495, -3.6156268, 0.12181739)
# 2025-01-20 18:10:10,458 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,459 INFO sqlalchemy.engine.Engine [cached since 0.3778s ago] (-3.4, 5.898167, -6.720013, -3.2357028, -0.23261862)
# 2025-01-20 18:10:10,460 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,461 INFO sqlalchemy.engine.Engine [cached since 0.3797s ago] (-3.3, 6.280164, -6.118162, -3.3633964, -0.43865138)
# 2025-01-20 18:10:10,462 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,463 INFO sqlalchemy.engine.Engine [cached since 0.382s ago] (-3.2, 5.76, -6.7660937, -3.2510889, 0.18313624)
# 2025-01-20 18:10:10,464 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,465 INFO sqlalchemy.engine.Engine [cached since 0.3842s ago] (-3.1, 5.418435, -6.2593627, -3.4713101, 0.22197495)
# 2025-01-20 18:10:10,466 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,467 INFO sqlalchemy.engine.Engine [cached since 0.3856s ago] (-3.0, 5.4701414, -5.8471675, -2.700972, 0.36851138)
# 2025-01-20 18:10:10,469 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,470 INFO sqlalchemy.engine.Engine [cached since 0.3892s ago] (-2.9, 4.9652553, -5.434099, -3.2628646, -0.14994985)
# 2025-01-20 18:10:10,472 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,472 INFO sqlalchemy.engine.Engine [cached since 0.3911s ago] (-2.8, 5.526654, -6.1166887, -2.370068, 0.6138541)
# 2025-01-20 18:10:10,473 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,474 INFO sqlalchemy.engine.Engine [cached since 0.3924s ago] (-2.7, 5.284998, -6.027501, -2.9662678, 0.3741298)
# 2025-01-20 18:10:10,474 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,475 INFO sqlalchemy.engine.Engine [cached since 0.3937s ago] (-2.6, 4.7569823, -5.008618, -2.23787, 0.08165933)
# 2025-01-20 18:10:10,476 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,476 INFO sqlalchemy.engine.Engine [cached since 0.3951s ago] (-2.5, 4.2834992, -5.014349, -2.1700747, 0.29023385)
# 2025-01-20 18:10:10,477 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,478 INFO sqlalchemy.engine.Engine [cached since 0.3963s ago] (-2.4, 4.191226, -4.7433724, -2.6651213, 0.58884114)
# 2025-01-20 18:10:10,478 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,479 INFO sqlalchemy.engine.Engine [cached since 0.3976s ago] (-2.3, 4.3178387, -5.33609, -1.8943019, -0.14863284)
# 2025-01-20 18:10:10,480 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,481 INFO sqlalchemy.engine.Engine [cached since 0.3994s ago] (-2.2, 3.8973043, -5.073695, -1.905655, -0.117682084)
# 2025-01-20 18:10:10,481 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,482 INFO sqlalchemy.engine.Engine [cached since 0.4008s ago] (-2.1, 3.844888, -5.061652, -1.6684194, 0.05557271)
# 2025-01-20 18:10:10,483 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,484 INFO sqlalchemy.engine.Engine [cached since 0.4024s ago] (-2.0, 4.270921, -4.5097136, -1.6928682, -0.12205349)
# 2025-01-20 18:10:10,485 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,487 INFO sqlalchemy.engine.Engine [cached since 0.4055s ago] (-1.9, 3.6676173, -3.9402707, -2.2605774, 0.25310782)
# 2025-01-20 18:10:10,488 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,490 INFO sqlalchemy.engine.Engine [cached since 0.4083s ago] (-1.8, 2.9909992, -4.1481814, -1.5290474, 0.20970975)
# 2025-01-20 18:10:10,491 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,491 INFO sqlalchemy.engine.Engine [cached since 0.4098s ago] (-1.7, 3.8140242, -3.8295608, -1.8965964, 0.5272478)
# 2025-01-20 18:10:10,492 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# 2025-01-20 18:10:10,493 INFO sqlalchemy.engine.Engine [cached since 0.4113s ago] (-1.6, 3.540481, -4.162029, -1.7526071, -0.35989845)
# 2025-01-20 18:10:10,493 INFO sqlalchemy.engine.Engine INSERT INTO training_data (x, y1, y2, y3, y4) VALUES (?, ?, ?, ?, ?)
# ...
# 2025-01-20 18:10:12,459 INFO sqlalchemy.engine.Engine [cached since 0.4992s ago] (-1.3, 17.94832, 18.9118782, 1)
# 2025-01-20 18:10:12,460 INFO sqlalchemy.engine.Engine SELECT ideal_functions.id AS ideal_functions_id, ideal_functions.x AS ideal_functions_x, ideal_functions.y1 AS ideal_functions_y1, ideal_functions.y2 AS ideal_functions_y2
# FROM ideal_functions
# WHERE ideal_functions.x = ?
#  LIMIT ? OFFSET ?
# 2025-01-20 18:10:12,461 INFO sqlalchemy.engine.Engine [cached since 0.5057s ago] (-4.6, 1, 0)
# 2025-01-20 18:10:12,463 INFO sqlalchemy.engine.Engine INSERT INTO test_results (x, y, delta_y, ideal_function_id) VALUES (?, ?, ?, ?)
# 2025-01-20 18:10:12,464 INFO sqlalchemy.engine.Engine [cached since 0.5036s ago] (-4.6, -3.321962, 4.315653, 1)
# 2025-01-20 18:10:12,465 INFO sqlalchemy.engine.Engine SELECT ideal_functions.id AS ideal_functions_id, ideal_functions.x AS ideal_functions_x, ideal_functions.y1 AS ideal_functions_y1, ideal_functions.y2 AS ideal_functions_y2
# FROM ideal_functions
# WHERE ideal_functions.x = ?
#  LIMIT ? OFFSET ?
# 2025-01-20 18:10:12,465 INFO sqlalchemy.engine.Engine [cached since 0.5099s ago] (-8.2, 1, 0)
# 2025-01-20 18:10:12,467 INFO sqlalchemy.engine.Engine INSERT INTO test_results (x, y, delta_y, ideal_function_id) VALUES (?, ?, ?, ?)
# 2025-01-20 18:10:12,468 INFO sqlalchemy.engine.Engine [cached since 0.5077s ago] (-8.2, 15.767493, 16.7082236, 1)
# 2025-01-20 18:10:12,469 INFO sqlalchemy.engine.Engine SELECT ideal_functions.id AS ideal_functions_id, ideal_functions.x AS ideal_functions_x, ideal_functions.y1 AS ideal_functions_y1, ideal_functions.y2 AS ideal_functions_y2
# FROM ideal_functions
# WHERE ideal_functions.x = ?
#  LIMIT ? OFFSET ?
# 2025-01-20 18:10:12,473 INFO sqlalchemy.engine.Engine [cached since 0.5171s ago] (13.3, 1, 0)
# 2025-01-20 18:10:12,475 INFO sqlalchemy.engine.Engine INSERT INTO test_results (x, y, delta_y, ideal_function_id) VALUES (?, ?, ?, ?)
# 2025-01-20 18:10:12,476 INFO sqlalchemy.engine.Engine [cached since 0.516s ago] (13.3, 27.148037, 26.478467199999997, 1)
# 2025-01-20 18:10:12,478 INFO sqlalchemy.engine.Engine SELECT ideal_functions.id AS ideal_functions_id, ideal_functions.x AS ideal_functions_x, ideal_functions.y1 AS ideal_functions_y1, ideal_functions.y2 AS ideal_functions_y2
# FROM ideal_functions
# WHERE ideal_functions.x = ?
#  LIMIT ? OFFSET ?
# 2025-01-20 18:10:12,478 INFO sqlalchemy.engine.Engine [cached since 0.5227s ago] (18.2, 1, 0)
# 2025-01-20 18:10:12,480 INFO sqlalchemy.engine.Engine INSERT INTO test_results (x, y, delta_y, ideal_function_id) VALUES (?, ?, ?, ?)
# 2025-01-20 18:10:12,481 INFO sqlalchemy.engine.Engine [cached since 0.5206s ago] (18.2, 18.535152, 19.1399848, 1)
# 2025-01-20 18:10:12,482 INFO sqlalchemy.engine.Engine SELECT ideal_functions.id AS ideal_functions_id, ideal_functions.x AS ideal_functions_x, ideal_functions.y1 AS ideal_functions_y1, ideal_functions.y2 AS ideal_functions_y2
# FROM ideal_functions
# WHERE ideal_functions.x = ?
#  LIMIT ? OFFSET ?
# 2025-01-20 18:10:12,482 INFO sqlalchemy.engine.Engine [cached since 0.5268s ago] (-10.0, 1, 0)
# 2025-01-20 18:10:12,484 INFO sqlalchemy.engine.Engine INSERT INTO test_results (x, y, delta_y, ideal_function_id) VALUES (?, ?, ?, ?)
# 2025-01-20 18:10:12,485 INFO sqlalchemy.engine.Engine [cached since 0.5251s ago] (-10.0, 18.979424, 18.435402900000003, 1)
# 2025-01-20 18:10:12,489 INFO sqlalchemy.engine.Engine SELECT ideal_functions.id AS ideal_functions_id, ideal_functions.x AS ideal_functions_x, ideal_functions.y1 AS ideal_functions_y1, ideal_functions.y2 AS ideal_functions_y2
# FROM ideal_functions
# WHERE ideal_functions.x = ?
#  LIMIT ? OFFSET ?
# 2025-01-20 18:10:12,490 INFO sqlalchemy.engine.Engine [cached since 0.5338s ago] (-12.0, 1, 0)
# 2025-01-20 18:10:12,492 INFO sqlalchemy.engine.Engine INSERT INTO test_results (x, y, delta_y, ideal_function_id) VALUES (?, ?, ?, ?)
# 2025-01-20 18:10:12,492 INFO sqlalchemy.engine.Engine [cached since 0.5321s ago] (-12.0, 0.670648, 0.13407507000000007, 1)
# 2025-01-20 18:10:12,494 INFO sqlalchemy.engine.Engine SELECT ideal_functions.id AS ideal_functions_id, ideal_functions.x AS ideal_functions_x, ideal_functions.y1 AS ideal_functions_y1, ideal_functions.y2 AS ideal_functions_y2
# FROM ideal_functions
# WHERE ideal_functions.x = ?
#  LIMIT ? OFFSET ?
# 2025-01-20 18:10:12,494 INFO sqlalchemy.engine.Engine [cached since 0.5385s ago] (18.7, 1, 0)
# 2025-01-20 18:10:12,496 INFO sqlalchemy.engine.Engine INSERT INTO test_results (x, y, delta_y, ideal_function_id) VALUES (?, ?, ?, ?)
# 2025-01-20 18:10:12,497 INFO sqlalchemy.engine.Engine [cached since 0.5364s ago] (18.7, 0.8322721, 0.9812711199999999, 1)
# 2025-01-20 18:10:12,498 INFO sqlalchemy.engine.Engine SELECT ideal_functions.id AS ideal_functions_id, ideal_functions.x AS ideal_functions_x, ideal_functions.y1 AS ideal_functions_y1, ideal_functions.y2 AS ideal_functions_y2
# FROM ideal_functions
# WHERE ideal_functions.x = ?
#  LIMIT ? OFFSET ?
# 2025-01-20 18:10:12,498 INFO sqlalchemy.engine.Engine [cached since 0.5426s ago] (-20.0, 1, 0)
# 2025-01-20 18:10:12,500 INFO sqlalchemy.engine.Engine INSERT INTO test_results (x, y, delta_y, ideal_function_id) VALUES (?, ?, ?, ?)
# 2025-01-20 18:10:12,501 INFO sqlalchemy.engine.Engine [cached since 0.5405s ago] (-20.0, -19.28497, 18.3720247, 1)
# 2025-01-20 18:10:12,502 INFO sqlalchemy.engine.Engine SELECT ideal_functions.id AS ideal_functions_id, ideal_functions.x AS ideal_functions_x, ideal_functions.y1 AS ideal_functions_y1, ideal_functions.y2 AS ideal_functions_y2
# FROM ideal_functions
# WHERE ideal_functions.x = ?
#  LIMIT ? OFFSET ?
# 2025-01-20 18:10:12,503 INFO sqlalchemy.engine.Engine [cached since 0.5469s ago] (12.5, 1, 0)
# 2025-01-20 18:10:12,507 INFO sqlalchemy.engine.Engine INSERT INTO test_results (x, y, delta_y, ideal_function_id) VALUES (?, ?, ?, ?)
# 2025-01-20 18:10:12,508 INFO sqlalchemy.engine.Engine [cached since 0.5473s ago] (12.5, 23.7267, 23.793021895000003, 1)
# 2025-01-20 18:10:12,509 INFO sqlalchemy.engine.Engine SELECT ideal_functions.id AS ideal_functions_id, ideal_functions.x AS ideal_functions_x, ideal_functions.y1 AS ideal_functions_y1, ideal_functions.y2 AS ideal_functions_y2
# FROM ideal_functions
# WHERE ideal_functions.x = ?
#  LIMIT ? OFFSET ?
# 2025-01-20 18:10:12,510 INFO sqlalchemy.engine.Engine [cached since 0.5541s ago] (-19.3, 1, 0)
# 2025-01-20 18:10:12,513 INFO sqlalchemy.engine.Engine INSERT INTO test_results (x, y, delta_y, ideal_function_id) VALUES (?, ?, ?, ?)
# 2025-01-20 18:10:12,514 INFO sqlalchemy.engine.Engine [cached since 0.5536s ago] (-19.3, -38.458572, 38.02320665, 1)
# 2025-01-20 18:10:12,515 INFO sqlalchemy.engine.Engine SELECT ideal_functions.id AS ideal_functions_id, ideal_functions.x AS ideal_functions_x, ideal_functions.y1 AS ideal_functions_y1, ideal_functions.y2 AS ideal_functions_y2
# FROM ideal_functions
# WHERE ideal_functions.x = ?
#  LIMIT ? OFFSET ?
# 2025-01-20 18:10:12,516 INFO sqlalchemy.engine.Engine [cached since 0.5601s ago] (16.3, 1, 0)
# 2025-01-20 18:10:12,518 INFO sqlalchemy.engine.Engine INSERT INTO test_results (x, y, delta_y, ideal_function_id) VALUES (?, ?, ?, ?)
# 2025-01-20 18:10:12,519 INFO sqlalchemy.engine.Engine [cached since 0.5584s ago] (16.3, 16.863394, 17.421446239999998, 1)
# 2025-01-20 18:10:12,522 INFO sqlalchemy.engine.Engine SELECT ideal_functions.id AS ideal_functions_id, ideal_functions.x AS ideal_functions_x, ideal_functions.y1 AS ideal_functions_y1, ideal_functions.y2 AS ideal_functions_y2
# FROM ideal_functions
# WHERE ideal_functions.x = ?
#  LIMIT ? OFFSET ?
# 2025-01-20 18:10:12,523 INFO sqlalchemy.engine.Engine [cached since 0.5676s ago] (6.7, 1, 0)
# 2025-01-20 18:10:12,525 INFO sqlalchemy.engine.Engine INSERT INTO test_results (x, y, delta_y, ideal_function_id) VALUES (?, ?, ?, ?)
# 2025-01-20 18:10:12,526 INFO sqlalchemy.engine.Engine [cached since 0.566s ago] (6.7, 6.232807, 5.82795708, 1)
# 2025-01-20 18:10:12,528 INFO sqlalchemy.engine.Engine SELECT ideal_functions.id AS ideal_functions_id, ideal_functions.x AS ideal_functions_x, ideal_functions.y1 AS ideal_functions_y1, ideal_functions.y2 AS ideal_functions_y2
# FROM ideal_functions
# WHERE ideal_functions.x = ?
#  LIMIT ? OFFSET ?
# 2025-01-20 18:10:12,528 INFO sqlalchemy.engine.Engine [cached since 0.5726s ago] (9.8, 1, 0)
# 2025-01-20 18:10:12,530 INFO sqlalchemy.engine.Engine INSERT INTO test_results (x, y, delta_y, ideal_function_id) VALUES (?, ?, ?, ?)
# 2025-01-20 18:10:12,531 INFO sqlalchemy.engine.Engine [cached since 0.5705s ago] (9.8, -21.007133, 20.64065387, 1)
# 2025-01-20 18:10:12,532 INFO sqlalchemy.engine.Engine SELECT ideal_functions.id AS ideal_functions_id, ideal_functions.x AS ideal_functions_x, ideal_functions.y1 AS ideal_functions_y1, ideal_functions.y2 AS ideal_functions_y2
# FROM ideal_functions
# WHERE ideal_functions.x = ?
#  LIMIT ? OFFSET ?
# 2025-01-20 18:10:12,533 INFO sqlalchemy.engine.Engine [cached since 0.5768s ago] (10.1, 1, 0)
# 2025-01-20 18:10:12,534 INFO sqlalchemy.engine.Engine INSERT INTO test_results (x, y, delta_y, ideal_function_id) VALUES (?, ?, ?, ?)
# 2025-01-20 18:10:12,535 INFO sqlalchemy.engine.Engine [cached since 0.5745s ago] (10.1, 20.669428, 21.29449863, 1)
# 2025-01-20 18:10:12,536 INFO sqlalchemy.engine.Engine SELECT ideal_functions.id AS ideal_functions_id, ideal_functions.x AS ideal_functions_x, ideal_functions.y1 AS ideal_functions_y1, ideal_functions.y2 AS ideal_functions_y2
# FROM ideal_functions
# WHERE ideal_functions.x = ?
#  LIMIT ? OFFSET ?
# 2025-01-20 18:10:12,538 INFO sqlalchemy.engine.Engine [cached since 0.5824s ago] (13.6, 1, 0)
# 2025-01-20 18:10:12,541 INFO sqlalchemy.engine.Engine INSERT INTO test_results (x, y, delta_y, ideal_function_id) VALUES (?, ?, ?, ?)
# 2025-01-20 18:10:12,542 INFO sqlalchemy.engine.Engine [cached since 0.5815s ago] (13.6, 28.536507, 27.6773452, 1)
# 2025-01-20 18:10:12,544 INFO sqlalchemy.engine.Engine SELECT ideal_functions.id AS ideal_functions_id, ideal_functions.x AS ideal_functions_x, ideal_functions.y1 AS ideal_functions_y1, ideal_functions.y2 AS ideal_functions_y2
# FROM ideal_functions
# WHERE ideal_functions.x = ?
#  LIMIT ? OFFSET ?
# 2025-01-20 18:10:12,545 INFO sqlalchemy.engine.Engine [cached since 0.5895s ago] (-14.4, 1, 0)
# 2025-01-20 18:10:12,547 INFO sqlalchemy.engine.Engine INSERT INTO test_results (x, y, delta_y, ideal_function_id) VALUES (?, ?, ?, ?)
# 2025-01-20 18:10:12,547 INFO sqlalchemy.engine.Engine [cached since 0.5873s ago] (-14.4, -15.698657, 14.7329992, 1)
# 2025-01-20 18:10:12,548 INFO sqlalchemy.engine.Engine SELECT ideal_functions.id AS ideal_functions_id, ideal_functions.x AS ideal_functions_x, ideal_functions.y1 AS ideal_functions_y1, ideal_functions.y2 AS ideal_functions_y2
# FROM ideal_functions
# WHERE ideal_functions.x = ?
#  LIMIT ? OFFSET ?
# 2025-01-20 18:10:12,549 INFO sqlalchemy.engine.Engine [cached since 0.5936s ago] (-9.1, 1, 0)
# 2025-01-20 18:10:12,551 INFO sqlalchemy.engine.Engine INSERT INTO test_results (x, y, delta_y, ideal_function_id) VALUES (?, ?, ?, ?)
# 2025-01-20 18:10:12,552 INFO sqlalchemy.engine.Engine [cached since 0.5924s ago] (-9.1, -31.648926, 31.32982765, 1)
# 2025-01-20 18:10:12,555 INFO sqlalchemy.engine.Engine SELECT ideal_functions.id AS ideal_functions_id, ideal_functions.x AS ideal_functions_x, ideal_functions.y1 AS ideal_functions_y1, ideal_functions.y2 AS ideal_functions_y2
# FROM ideal_functions
# WHERE ideal_functions.x = ?
#  LIMIT ? OFFSET ?
# 2025-01-20 18:10:12,556 INFO sqlalchemy.engine.Engine [cached since 0.6011s ago] (16.6, 1, 0)
# 2025-01-20 18:10:12,559 INFO sqlalchemy.engine.Engine INSERT INTO test_results (x, y, delta_y, ideal_function_id) VALUES (?, ?, ?, ?)
# 2025-01-20 18:10:12,560 INFO sqlalchemy.engine.Engine [cached since 0.5996s ago] (16.6, -33.41535, 32.6369979, 1)
# 2025-01-20 18:10:12,561 INFO sqlalchemy.engine.Engine SELECT ideal_functions.id AS ideal_functions_id, ideal_functions.x AS ideal_functions_x, ideal_functions.y1 AS ideal_functions_y1, ideal_functions.y2 AS ideal_functions_y2
# FROM ideal_functions
# WHERE ideal_functions.x = ?
#  LIMIT ? OFFSET ?
# 2025-01-20 18:10:12,562 INFO sqlalchemy.engine.Engine [cached since 0.6062s ago] (-12.4, 1, 0)
# 2025-01-20 18:10:12,563 INFO sqlalchemy.engine.Engine INSERT INTO test_results (x, y, delta_y, ideal_function_id) VALUES (?, ?, ?, ?)
# 2025-01-20 18:10:12,564 INFO sqlalchemy.engine.Engine [cached since 0.6039s ago] (-12.4, 26.599438, 26.433833829999998, 1)
# 2025-01-20 18:10:12,565 INFO sqlalchemy.engine.Engine SELECT ideal_functions.id AS ideal_functions_id, ideal_functions.x AS ideal_functions_x, ideal_functions.y1 AS ideal_functions_y1, ideal_functions.y2 AS ideal_functions_y2
# FROM ideal_functions
# WHERE ideal_functions.x = ?
#  LIMIT ? OFFSET ?
# 2025-01-20 18:10:12,566 INFO sqlalchemy.engine.Engine [cached since 0.6101s ago] (-1.9, 1, 0)
# 2025-01-20 18:10:12,567 INFO sqlalchemy.engine.Engine INSERT INTO test_results (x, y, delta_y, ideal_function_id) VALUES (?, ?, ?, ?)
# 2025-01-20 18:10:12,568 INFO sqlalchemy.engine.Engine [cached since 0.6078s ago] (-1.9, -4.0369043, 3.0906041999999996, 1)
# 2025-01-20 18:10:12,569 INFO sqlalchemy.engine.Engine SELECT ideal_functions.id AS ideal_functions_id, ideal_functions.x AS ideal_functions_x, ideal_functions.y1 AS ideal_functions_y1, ideal_functions.y2 AS ideal_functions_y2
# FROM ideal_functions
# WHERE ideal_functions.x = ?
#  LIMIT ? OFFSET ?
# 2025-01-20 18:10:12,571 INFO sqlalchemy.engine.Engine [cached since 0.6157s ago] (12.2, 1, 0)
# 2025-01-20 18:10:12,576 INFO sqlalchemy.engine.Engine INSERT INTO test_results (x, y, delta_y, ideal_function_id) VALUES (?, ?, ?, ?)
# 2025-01-20 18:10:12,576 INFO sqlalchemy.engine.Engine [cached since 0.6164s ago] (12.2, -0.010358215, 0.347871065, 1)
# 2025-01-20 18:10:12,578 INFO sqlalchemy.engine.Engine SELECT ideal_functions.id AS ideal_functions_id, ideal_functions.x AS ideal_functions_x, ideal_functions.y1 AS ideal_functions_y1, ideal_functions.y2 AS ideal_functions_y2
# FROM ideal_functions
# WHERE ideal_functions.x = ?
#  LIMIT ? OFFSET ?
# 2025-01-20 18:10:12,578 INFO sqlalchemy.engine.Engine [cached since 0.6229s ago] (16.5, 1, 0)
# 2025-01-20 18:10:12,580 INFO sqlalchemy.engine.Engine INSERT INTO test_results (x, y, delta_y, ideal_function_id) VALUES (?, ?, ?, ?)
# 2025-01-20 18:10:12,581 INFO sqlalchemy.engine.Engine [cached since 0.6209s ago] (16.5, -33.964134, 33.2523487, 1)
# 2025-01-20 18:10:12,582 INFO sqlalchemy.engine.Engine SELECT ideal_functions.id AS ideal_functions_id, ideal_functions.x AS ideal_functions_x, ideal_functions.y1 AS ideal_functions_y1, ideal_functions.y2 AS ideal_functions_y2
# FROM ideal_functions
# WHERE ideal_functions.x = ?
#  LIMIT ? OFFSET ?
# 2025-01-20 18:10:12,583 INFO sqlalchemy.engine.Engine [cached since 0.6272s ago] (5.3, 1, 0)
# 2025-01-20 18:10:12,585 INFO sqlalchemy.engine.Engine INSERT INTO test_results (x, y, delta_y, ideal_function_id) VALUES (?, ?, ?, ?)
# 2025-01-20 18:10:12,588 INFO sqlalchemy.engine.Engine [cached since 0.628s ago] (5.3, -10.291622, 9.45935454, 1)
# 2025-01-20 18:10:12,590 INFO sqlalchemy.engine.Engine SELECT ideal_functions.id AS ideal_functions_id, ideal_functions.x AS ideal_functions_x, ideal_functions.y1 AS ideal_functions_y1, ideal_functions.y2 AS ideal_functions_y2
# FROM ideal_functions
# WHERE ideal_functions.x = ?
#  LIMIT ? OFFSET ?
# 2025-01-20 18:10:12,591 INFO sqlalchemy.engine.Engine [cached since 0.6355s ago] (17.9, 1, 0)
# 2025-01-20 18:10:12,593 INFO sqlalchemy.engine.Engine INSERT INTO test_results (x, y, delta_y, ideal_function_id) VALUES (?, ?, ?, ?)
# 2025-01-20 18:10:12,594 INFO sqlalchemy.engine.Engine [cached since 0.6336s ago] (17.9, 28.078455, 28.891612140000003, 1)
# 2025-01-20 18:10:12,595 INFO sqlalchemy.engine.Engine COMMIT
# 2025-01-20 18:10:12,600 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-01-20 18:10:12,602 INFO sqlalchemy.engine.Engine SELECT test_results.id AS test_results_id, test_results.x AS test_results_x, test_results.y AS test_results_y, test_results.delta_y AS test_results_delta_y, test_results.ideal_function_id AS test_results_ideal_function_id
# FROM test_results
# 2025-01-20 18:10:12,603 INFO sqlalchemy.engine.Engine [generated in 0.00091s] ()
